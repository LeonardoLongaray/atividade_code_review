# %%
def escolha_um_numero(primeiro):
    if primeiro < 0:
        raise ValueError("O número deve ser não-negativo.")
    elif primeiro == 0:
        return('tu podia ter escolhido um número maior que 0 né')
    return(primeiro * 2)

# %%
escolha_um_numero()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 escolha_um_numero()
#
# TypeError: escolha_um_numero() missing 1 required positional argument: 'primeiro'
